# %% [markdown]
# $$
# \newcommand{\mat}[1]{\boldsymbol {#1}}
# \newcommand{\mattr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\matinv}[1]{\boldsymbol {#1}^{-1}}
# \newcommand{\vec}[1]{\boldsymbol {#1}}
# \newcommand{\vectr}[1]{\boldsymbol {#1}^\top}
# \newcommand{\rvar}[1]{\mathrm {#1}}
# \newcommand{\rvec}[1]{\boldsymbol{\mathrm{#1}}}
# \newcommand{\diag}{\mathop{\mathrm {diag}}}
# \newcommand{\set}[1]{\mathbb {#1}}
# \newcommand{\norm}[1]{\left\lVert#1\right\rVert}
# \newcommand{\pderiv}[2]{\frac{\partial #1}{\partial #2}}
# \newcommand{\bm}[1]{{\bf #1}}
# \newcommand{\bb}[1]{\bm{\mathrm{#1}}}
# $$
#
# # Part 2: Variational Autoencoder
# <a id=part2></a>

# %% [markdown]
# In this part we will learn to generate new data using a special type of autoencoder model which allows us to
# sample from its latent space. We'll implement and train a VAE and use it to generate new images.

# %%
import unittest
import os
import sys
import pathlib
import urllib
import shutil
import re
import zipfile

import numpy as np
import torch
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
test = unittest.TestCase()
plt.rcParams.update({'font.size': 12})
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# ### Obtaining the dataset
# <a id=part2_1></a>

# %% [markdown]
# Let's begin by downloading a dataset of images that we want to learn to generate.
# We'll use the [Labeled Faces in the Wild](http://vis-www.cs.umass.edu/lfw/) (LFW) dataset which contains many labeled faces of famous individuals.
#
# We're going to train our generative model to generate a specific face, not just any face.
# Since the person with the most images in this dataset is former president George W. Bush, we'll set out to train a Bush Generator :)
#
# However, if you feel adventurous and/or prefer to generate something else, feel free to edit the `PART2_CUSTOM_DATA_URL` variable in `hw3/answers.py`.

# %%
import cs236781.plot as plot
import cs236781.download
from hw3.answers import PART2_CUSTOM_DATA_URL as CUSTOM_DATA_URL

DATA_DIR = pathlib.Path.home().joinpath('.pytorch-datasets')
if CUSTOM_DATA_URL is None:
    DATA_URL = 'http://vis-www.cs.umass.edu/lfw/lfw-bush.zip'
else:
    DATA_URL = CUSTOM_DATA_URL

_, dataset_dir = cs236781.download.download_data(out_path=DATA_DIR, url=DATA_URL, extract=True, force=False)
# Out:
# File /home/sleemann/.pytorch-datasets/George_W_Bush2.zip exists, skipping download.
# Extracting /home/sleemann/.pytorch-datasets/George_W_Bush2.zip...
# Extracted 532 to /home/sleemann/.pytorch-datasets/George_W_Bush/George_W_Bush

# %% [markdown]
# Create a `Dataset` object that will load the extraced images:

# %%
import torchvision.transforms as T
from torchvision.datasets import ImageFolder

im_size = 64
tf = T.Compose([
    # Resize to constant spatial dimensions
    T.Resize((im_size, im_size)),
    # PIL.Image -> torch.Tensor
    T.ToTensor(),
    # Dynamic range [0,1] -> [-1, 1]
    T.Normalize(mean=(.5,.5,.5), std=(.5,.5,.5)),
])

ds_gwb = ImageFolder(os.path.dirname(dataset_dir), tf)

# %% [markdown]
# OK, let's see what we got. You can run the following block multiple times to display a random subset of images from the dataset.

# %%
_ = plot.dataset_first_n(ds_gwb, 50, figsize=(15,10), nrows=5)
print(f'Found {len(ds_gwb)} images in dataset folder.')
# Out:
# Found 530 images in dataset folder.

# %%
x0, y0 = ds_gwb[0]
x0 = x0.unsqueeze(0).to(device)
print(x0.shape)

test.assertSequenceEqual(x0.shape, (1, 3, im_size, im_size))
# Out:
# torch.Size([1, 3, 64, 64])

# %% [markdown]
# ## The Variational Autoencoder
# <a id=part2_2></a>

# %% [markdown]
# An autoencoder is a model which learns a representation of data in an **unsupervised** fashion (i.e without any labels).
# Recall it's general form from the lecture:
#
# <img src="imgs/autoencoder.jpg"/>

# %% [markdown]
# An autoencoder maps an instance $\bb{x}$ to a **latent-space** representation $\bb{z}$.
# It has an encoder part, $\Phi_{\bb{\alpha}}(\bb{x})$ (a model with parameters $\bb{\alpha}$)
# and a decoder part, $\Psi_{\bb{\beta}}(\bb{z})$ (a model with parameters $\bb{\beta}$).
#
# While autoencoders can learn useful representations,
# generally it's hard to use them as generative models because there's no distribution we can sample from in the latent space. In other words, we have no way to choose a point $\bb{z}$ in the latent space
# such that $\Psi(\bb{z})$ will end up on the data manifold in the instance space.
#
# <img src="imgs/ae_sampling.jpg"/>

# %% [markdown]
# The variational autoencoder (VAE), first proposed by [Kingma and Welling](https://arxiv.org/pdf/1312.6114.pdf), addresses this issue by taking a probabilistic perspective.
# Briefly, a VAE model can be described as follows.
#
# We define, in Baysean terminology,
# - The **prior** distribution $p(\bb{Z})$ on points in the latent space.
# - The **posterior** distribution of points in the latent spaces given a specific instance: $p(\bb{Z}|\bb{X})$.
# - The **likelihood** distribution of a sample $\bb{X}$ given a latent-space representation: $p(\bb{X}|\bb{Z})$.
# - The **evidence** distribution $p(\bb{X})$ which is the distribution of the instance space due to the generative process.

# %% [markdown]
# To create our variational **decoder** we'll further specify:
#
# - A parametric likelihood distribution, $p _{\bb{\beta}}(\bb{X} | \bb{Z}=\bb{z}) = \mathcal{N}( \Psi _{\bb{\beta}}(\bb{z}) , \sigma^2 \bb{I} )$. The interpretation is that given a latent $\bb{z}$, we map it to a point normally distributed around the point calculated by our decoder neural network. Note that here $\sigma^2$ is a hyperparameter while $\vec{\beta}$ represents the network parameters.
# - A fixed latent-space prior distribution of $p(\bb{Z}) = \mathcal{N}(\bb{0},\bb{I})$.
#
# This setting allows us to generate a new instance $\bb{x}$ by sampling $\bb{z}$ from the multivariate normal
# distribution, obtaining the instance-space mean $\Psi _{\bb{\beta}}(\bb{z})$ using our decoder network,
# and then sampling $\bb{x}$ from $\mathcal{N}( \Psi _{\bb{\beta}}(\bb{z}) , \sigma^2 \bb{I} )$.

# %% [markdown]
# Our variational **encoder** will approximate the posterior with a parametric distribution
# $q _{\bb{\alpha}}(\bb{Z} | \bb{x}) =
# \mathcal{N}( \bb{\mu} _{\bb{\alpha}}(\bb{x}),  \mathrm{diag}\{ \bb{\sigma}^2_{\bb{\alpha}}(\bb{x}) \} )$.
# The interpretation is that our encoder model, $\Phi_{\vec{\alpha}}(\bb{x})$, calculates
# the mean and variance of the posterior distribution, and samples $\bb{z}$ based on them.
# An important nuance here is that our network can't contain any stochastic elements that
# depend on the model parameters, otherwise we won't be able to back-propagate to those parameters.
# So sampling $\bb{z}$ from $\mathcal{N}( \bb{\mu} _{\bb{\alpha}}(\bb{x}),  \mathrm{diag}\{ \bb{\sigma}^2_{\bb{\alpha}}(\bb{x}) \} )$ is not an option.
# The solution is to use what's known as the **reparametrization trick**: sample from an isotropic Gaussian,
# i.e. $\bb{u}\sim\mathcal{N}(\bb{0},\bb{I})$ (which doesn't depend on trainable parameters), and calculate the latent representation as
# $\bb{z} = \bb{\mu} _{\bb{\alpha}}(\bb{x}) + \bb{u}\odot\bb{\sigma}_{\bb{\alpha}}(\bb{x})$.

# %% [markdown]
# To train a VAE model, we maximize the evidence distribution, $p(\bb{X})$ (see question below).
# The **VAE loss** can therefore be stated as minimizing $\mathcal{L} = -\mathbb{E}_{\bb{x}} \log p(\bb{X})$.
# Although this expectation is intractable,
# we can obtain a lower-bound for $p(\bb{X})$ (the evidence lower bound, "ELBO", shown in the lecture):
#
# $$
# \log p(\bb{X}) \ge \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }\left[ \log  p _{\bb{\beta}}(\bb{X} | \bb{z}) \right]
# -  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{X})\,\left\|\, p(\bb{Z} )\right.\right)
# $$
#
# where
# $
# \mathcal{D} _{\mathrm{KL}}(q\left\|\right.p) =
# \mathbb{E}_{\bb{z}\sim q}\left[ \log \frac{q(\bb{Z})}{p(\bb{Z})} \right]
# $
# is the Kullback-Liebler divergence, which can be interpreted as the information gained by using the posterior $q(\bb{Z|X})$ instead of the prior distribution $p(\bb{Z})$.
#
# Using the ELBO, the VAE loss becomes,
# $$
# \mathcal{L}(\vec{\alpha},\vec{\beta}) = \mathbb{E} _{\bb{x}}  \left[
# \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }\left[ -\log  p _{\bb{\beta}}(\bb{x} | \bb{z}) \right]
# +  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{x})\,\left\|\, p(\bb{Z} )\right.\right)
# \right].
# $$
#
# By remembering that the likelihood is a Gaussian distribution with a diagonal covariance and by applying the reparametrization trick, we can write the above as
#
# $$
# \mathcal{L}(\vec{\alpha},\vec{\beta}) = \mathbb{E} _{\bb{x}}  \left[
# \mathbb{E} _{\bb{z} \sim q _{\bb{\alpha}} }
# \left[
# \frac{1}{2\sigma^2}\left\| \bb{x}- \Psi _{\bb{\beta}}\left(  \bb{\mu} _{\bb{\alpha}}(\bb{x})  + \bb{\Sigma}^{\frac{1}{2}} _{\bb{\alpha}}(\bb{x}) \bb{u}   \right) \right\| _2^2
# \right]
# +  \mathcal{D} _{\mathrm{KL}}\left(q _{\bb{\alpha}}(\bb{Z} | \bb{x})\,\left\|\, p(\bb{Z} )\right.\right)
# \right].
# $$

# %% [markdown]
# ### Model Implementation
# <a id=part2_3></a>

# %% [markdown]
# Obviously our model will have two parts, an encoder and a decoder.
# Since we're working with images, we'll implement both as deep **convolutional** networks, where the decoder is a "mirror image" of the encoder implemented with adjoint (AKA transposed) convolutions.
# Between the encoder CNN and the decoder CNN we'll implement the sampling from
# the parametric posterior approximator $q_{\bb{\alpha}}(\bb{Z}|\bb{x})$
# to make it a VAE model and not just a regular autoencoder (of course, this is not yet enough to create a VAE,
# since we also need a special loss function which we'll get to later).

# %% [markdown]
# First let's implement just the CNN part of the Encoder network
# (this is not the full $\Phi_{\vec{\alpha}}(\bb{x})$ yet).
# As usual, it should take an input image and map to a activation volume of a specified depth.
# We'll consider this volume as the features we extract from the input image.
# Later we'll use these to create the latent space representation of the input.

# %% [markdown]
# **TODO**: Implement the `EncoderCNN` class in the `hw3/autoencoder.py` module.
# Implement any CNN architecture you like. If you need "architecture inspiration" you can see e.g. [this](https://arxiv.org/pdf/1512.09300.pdf) or [this](https://arxiv.org/pdf/1511.06434.pdf) paper.

# %%
import hw3.autoencoder as autoencoder

in_channels = 3
out_channels = 1024
encoder_cnn = autoencoder.EncoderCNN(in_channels, out_channels).to(device)
print(encoder_cnn)

h = encoder_cnn(x0)
print(h.shape)

test.assertEqual(h.dim(), 4)
test.assertSequenceEqual(h.shape[0:2], (1, out_channels))
# Out:
# EncoderCNN(
#   (encoder_dropout): Dropout(p=0.25, inplace=False)
#   (cnn): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): LeakyReLU(negative_slope=0.2)
#     (7): Dropout(p=0.25, inplace=False)
#     (8): Conv2d(128, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Dropout(p=0.25, inplace=False)
#     (12): Conv2d(256, 1024, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#     (13): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): LeakyReLU(negative_slope=0.2)
#     (15): Dropout(p=0.25, inplace=False)
#   )
# )
# torch.Size([1, 1024, 4, 4])

# %% [markdown]
# Now let's implement the CNN part of the Decoder.
# Again this is not yet the full $\Psi _{\bb{\beta}}(\bb{z})$. It should take an activation volume produced
# by your `EncoderCNN` and output an image of the same dimensions as the Encoder's input was.
# This can be a CNN which is like a "mirror image" of the the Encoder. For example, replace convolutions with transposed convolutions, downsampling with up-sampling etc.
# Consult the documentation of [ConvTranspose2D](https://pytorch.org/docs/0.4.1/nn.html#convtranspose2d)
# to figure out how to reverse your convolutional layers in terms of input and output dimensions. Note that the decoder doesn't have to be exactly the opposite of the encoder and you can experiment with using a different architecture.

# %% [markdown]
# **TODO**: Implement the `DecoderCNN` class in the `hw3/autoencoder.py` module.

# %%
decoder_cnn = autoencoder.DecoderCNN(in_channels=out_channels, out_channels=in_channels).to(device)
print(decoder_cnn)
x0r = decoder_cnn(h)
print(x0r.shape)

test.assertEqual(x0.shape, x0r.shape)

# Should look like colored noise
T.functional.to_pil_image(x0r[0].cpu().detach())
# Out:
# DecoderCNN(
#   (decoder_dropout): Dropout(p=0.25, inplace=False)
#   (cnn): Sequential(
#     (0): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): LeakyReLU(negative_slope=0.2)
#     (7): Dropout(p=0.25, inplace=False)
#     (8): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): LeakyReLU(negative_slope=0.2)
#     (11): Dropout(p=0.25, inplace=False)
#     (12): ConvTranspose2d(128, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (13): Tanh()
#   )
# )
# torch.Size([1, 3, 64, 64])
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F5DB0AAD820>

# %% [markdown]
# Let's now implement the full VAE Encoder, $\Phi_{\vec{\alpha}}(\vec{x})$.
# It will work as follows:
# 1. Produce a feature vector $\vec{h}$ from the input image $\vec{x}$.
# 2. Use two affine transforms to convert the features into the mean and log-variance of the posterior, i.e.
#     $$
#     \begin{align}
#         \bb{\mu} _{\bb{\alpha}}(\bb{x}) &= \vec{h}\mattr{W}_{\mathrm{h\mu}} + \vec{b}_{\mathrm{h\mu}} \\
#         \log\left(\bb{\sigma}^2_{\bb{\alpha}}(\bb{x})\right) &= \vec{h}\mattr{W}_{\mathrm{h\sigma^2}} + \vec{b}_{\mathrm{h\sigma^2}}
#     \end{align}
#     $$
# 3. Use the **reparametrization trick** to create the latent representation $\vec{z}$.
#
# Notice that we model the **log** of the variance, not the actual variance.
# The above formulation is proposed in appendix C of the [VAE paper](https://arxiv.org/pdf/1312.6114.pdf).

# %% [markdown]
# **TODO**: Implement the `encode()` method in the `VAE` class within the `hw3/autoencoder.py` module.
# You'll also need to define your parameters in `__init__()`.

# %%
z_dim = 2
vae = autoencoder.VAE(encoder_cnn, decoder_cnn, x0[0].size(), z_dim).to(device)
print(vae)

z, mu, log_sigma2 = vae.encode(x0)

test.assertSequenceEqual(z.shape, (1, z_dim))
test.assertTrue(z.shape == mu.shape == log_sigma2.shape)

print(f'mu(x0)={list(*mu.detach().cpu().numpy())}, sigma2(x0)={list(*torch.exp(log_sigma2).detach().cpu().numpy())}')
# Out:
# VAE(
#   (features_encoder): EncoderCNN(
#     (encoder_dropout): Dropout(p=0.25, inplace=False)
#     (cnn): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Dropout(p=0.25, inplace=False)
#       (4): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): LeakyReLU(negative_slope=0.2)
#       (7): Dropout(p=0.25, inplace=False)
#       (8): Conv2d(128, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (10): LeakyReLU(negative_slope=0.2)
#       (11): Dropout(p=0.25, inplace=False)
#       (12): Conv2d(256, 1024, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (13): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): LeakyReLU(negative_slope=0.2)
#       (15): Dropout(p=0.25, inplace=False)
#     )
#   )
#   (features_decoder): DecoderCNN(
#     (decoder_dropout): Dropout(p=0.25, inplace=False)
#     (cnn): Sequential(
#       (0): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Dropout(p=0.25, inplace=False)
#       (4): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): LeakyReLU(negative_slope=0.2)
#       (7): Dropout(p=0.25, inplace=False)
#       (8): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (10): LeakyReLU(negative_slope=0.2)
#       (11): Dropout(p=0.25, inplace=False)
#       (12): ConvTranspose2d(128, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (13): Tanh()
#     )
#   )
#   (fc_mu): Linear(in_features=16384, out_features=2, bias=True)
#   (fc_logvar): Linear(in_features=16384, out_features=2, bias=True)
#   (fc_z): Linear(in_features=2, out_features=16384, bias=True)
# )
# mu(x0)=[-2.3515549, 0.043507278], sigma2(x0)=[1.3995899, 2.0913742]

# %% [markdown]
# Let's sample some 2d latent representations for an input image `x0` and visualize them.

# %%
# Sample from q(Z|x)
N = 500
Z = torch.zeros(N, z_dim)
_, ax = plt.subplots()
with torch.no_grad():
    for i in range(N):
        Z[i], _, _ = vae.encode(x0)
        ax.scatter(*Z[i].cpu().numpy())

# Should be close to the mu/sigma in the previous block above
print('sampled mu', torch.mean(Z, dim=0))
print('sampled sigma2', torch.var(Z, dim=0))
# Out:
# sampled mu tensor([-2.5989, -0.3292])
# sampled sigma2 tensor([2.7017, 5.7622])

# %% [markdown]
# Let's now implement the full VAE Decoder, $\Psi _{\bb{\beta}}(\bb{z})$.
# It will work as follows:
# 1. Produce a feature vector $\tilde{\vec{h}}$ from the latent vector $\vec{z}$ using an affine transform.
# 2. Reconstruct an image $\tilde{\vec{x}}$ from $\tilde{\vec{h}}$ using the decoder CNN.

# %% [markdown]
# **TODO**: Implement the `decode()` method in the `VAE` class within the `hw3/autoencoder.py` module.
# You'll also need to define your parameters in `__init__()`. You may need to also re-run the block above after you implement this.

# %%
x0r = vae.decode(z)

test.assertSequenceEqual(x0r.shape, x0.shape)

# %% [markdown]
# Our model's `forward()` function will simply return `decode(encode(x))` as well as the calculated mean and log-variance of the posterior.

# %%
x0r, mu, log_sigma2 = vae(x0)

test.assertSequenceEqual(x0r.shape, x0.shape)
test.assertSequenceEqual(mu.shape, (1, z_dim))
test.assertSequenceEqual(log_sigma2.shape, (1, z_dim))
T.functional.to_pil_image(x0r[0].detach().cpu())
# Out:
# <PIL.Image.Image image mode=RGB size=64x64 at 0x7F5D3596DF40>

# %% [markdown]
# ### Loss Implementation
# <a id=part2_4></a>

# %% [markdown]
# In practice, since we're using SGD, we'll drop the expectation over $\bb{X}$ and instead sample an instance from the training set and compute a point-wise loss. Similarly, we'll drop the expectation over $\bb{Z}$ by sampling from $q_{\vec{\alpha}}(\bb{Z}|\bb{x})$.
# Additionally, because the KL divergence is between two Gaussian distributions, there is a closed-form expression for it. These points bring us to the following point-wise loss:
#
# $$
# \ell(\vec{\alpha},\vec{\beta};\bb{x}) =
# \frac{1}{\sigma^2 d_x} \left\| \bb{x}- \Psi _{\bb{\beta}}\left(  \bb{\mu} _{\bb{\alpha}}(\bb{x})  +
# \bb{\Sigma}^{\frac{1}{2}} _{\bb{\alpha}}(\bb{x}) \bb{u}   \right) \right\| _2^2 +
# \mathrm{tr}\,\bb{\Sigma} _{\bb{\alpha}}(\bb{x}) +  \|\bb{\mu} _{\bb{\alpha}}(\bb{x})\|^2 _2 - d_z - \log\det \bb{\Sigma} _{\bb{\alpha}}(\bb{x}),
# $$
#
# where $d_z$ is the dimension of the latent space, $d_x$ is the dimension of the input and $\bb{u}\sim\mathcal{N}(\bb{0},\bb{I})$.
# This pointwise loss is the quantity that we'll compute and minimize with gradient descent.
# The first term corresponds to the data-reconstruction loss, while the second term corresponds to the KL-divergence loss.
# Note that the scaling by $d_x$ is not derived from the original loss formula and was added directly to the pointwise loss just to normalize the data term.

# %% [markdown]
# **TODO**: Implement the `vae_loss()` function in the `hw3/autoencoder.py` module.

# %%
from hw3.autoencoder import vae_loss
torch.manual_seed(42)

def test_vae_loss():
    # Test data
    N, C, H, W = 10, 3, 64, 64 
    z_dim = 32
    x  = torch.randn(N, C, H, W)*2 - 1
    xr = torch.randn(N, C, H, W)*2 - 1
    z_mu = torch.randn(N, z_dim)
    z_log_sigma2 = torch.randn(N, z_dim)
    x_sigma2 = 0.9
    
    loss, _, _ = vae_loss(x, xr, z_mu, z_log_sigma2, x_sigma2)
    
    test.assertAlmostEqual(loss.item(), 58.3234367, delta=1e-3)
    return loss

test_vae_loss()
# Out:
# tensor(58.3234)

# %% [markdown]
# ### Sampling
# <a id=part2_5></a>

# %% [markdown]
# The main advantage of a VAE is that it can by used as a generative model by sampling the latent space, since
# we optimize for a isotropic Gaussian prior $p(\bb{Z})$ in the loss function. Let's now implement this so that we can visualize how our model is doing when we train.

# %% [markdown]
# **TODO**: Implement the `sample()` method in the `VAE` class within the `hw3/autoencoder.py` module.

# %%
samples = vae.sample(5)
_ = plot.tensors_as_images(samples)

# %% [markdown]
# ### Training
# <a id=part2_6></a>

# %% [markdown]
# Time to train!

# %% [markdown]
# **TODO**:
# 1. Implement the `VAETrainer` class in the `hw3/training.py` module. Make sure to implement the `checkpoints` feature of the `Trainer` class if you haven't done so already in Part 1.
# 2. Tweak the hyperparameters in the `part2_vae_hyperparams()` function within the `hw3/answers.py` module.

# %%
import torch.optim as optim
from torch.utils.data import random_split
from torch.utils.data import DataLoader
from torch.nn import DataParallel
from hw3.training import VAETrainer
from hw3.answers import part2_vae_hyperparams

torch.manual_seed(42)

# Hyperparams
hp = part2_vae_hyperparams()
batch_size = hp['batch_size']
h_dim = hp['h_dim']
z_dim = hp['z_dim']
x_sigma2 = hp['x_sigma2']
learn_rate = hp['learn_rate']
betas = hp['betas']

# Data
split_lengths = [int(len(ds_gwb)*0.9), int(len(ds_gwb)*0.1)]
ds_train, ds_test = random_split(ds_gwb, split_lengths)
dl_train = DataLoader(ds_train, batch_size, shuffle=True)
dl_test  = DataLoader(ds_test,  batch_size, shuffle=True)
im_size = ds_train[0][0].shape

# Model
encoder = autoencoder.EncoderCNN(in_channels=im_size[0], out_channels=h_dim)
decoder = autoencoder.DecoderCNN(in_channels=h_dim, out_channels=im_size[0])
vae = autoencoder.VAE(encoder, decoder, im_size, z_dim)
vae_dp = DataParallel(vae).to(device)

# Optimizer
optimizer = optim.Adam(vae.parameters(), lr=learn_rate, betas=betas)

# Loss
def loss_fn(x, xr, z_mu, z_log_sigma2):
    return autoencoder.vae_loss(x, xr, z_mu, z_log_sigma2, x_sigma2)

# Trainer
trainer = VAETrainer(vae_dp, loss_fn, optimizer, device)
checkpoint_file = 'checkpoints/vae'
checkpoint_file_final = f'{checkpoint_file}_final'
if os.path.isfile(f'{checkpoint_file}.pt'):
    os.remove(f'{checkpoint_file}.pt')

# Show model and hypers
print(vae)
print(hp)
# Out:
# VAE(
#   (features_encoder): EncoderCNN(
#     (encoder_dropout): Dropout(p=0.25, inplace=False)
#     (cnn): Sequential(
#       (0): Conv2d(3, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Dropout(p=0.25, inplace=False)
#       (4): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (5): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): LeakyReLU(negative_slope=0.2)
#       (7): Dropout(p=0.25, inplace=False)
#       (8): Conv2d(128, 256, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (9): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (10): LeakyReLU(negative_slope=0.2)
#       (11): Dropout(p=0.25, inplace=False)
#       (12): Conv2d(256, 512, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#       (13): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (14): LeakyReLU(negative_slope=0.2)
#       (15): Dropout(p=0.25, inplace=False)
#     )
#   )
#   (features_decoder): DecoderCNN(
#     (decoder_dropout): Dropout(p=0.25, inplace=False)
#     (cnn): Sequential(
#       (0): ConvTranspose2d(512, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#       (3): Dropout(p=0.25, inplace=False)
#       (4): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (6): LeakyReLU(negative_slope=0.2)
#       (7): Dropout(p=0.25, inplace=False)
#       (8): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (9): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (10): LeakyReLU(negative_slope=0.2)
#       (11): Dropout(p=0.25, inplace=False)
#       (12): ConvTranspose2d(128, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#       (13): Tanh()
#     )
#   )
#   (fc_mu): Linear(in_features=8192, out_features=64, bias=True)
#   (fc_logvar): Linear(in_features=8192, out_features=64, bias=True)
#   (fc_z): Linear(in_features=64, out_features=8192, bias=True)
# )
# {'batch_size': 96, 'h_dim': 512, 'z_dim': 64, 'x_sigma2': 0.00025, 'learn_rate': 0.00018, 'betas': (0.9, 0.999)}

# %% [markdown]
# **TODO**:
# 1. Run the following block to train. It will sample some images from your model every few epochs so you can see the progress.
# 2. When you're satisfied with your results, rename the checkpoints file by adding `_final`. When you run the `main.py` script to generate your submission, the final checkpoints file will be loaded instead of running training. Note that your final submission zip will not include the `checkpoints/` folder. This is OK.
#
# The images you get should be colorful, with different backgrounds and poses.

# %%
import IPython.display

def post_epoch_fn(epoch, train_result, test_result, verbose):
    # Plot some samples if this is a verbose epoch
    if verbose:
        samples = vae.sample(n=5)
        fig, _ = plot.tensors_as_images(samples, figsize=(6,2))
        IPython.display.display(fig)
        plt.close(fig)

if os.path.isfile(f'{checkpoint_file_final}.pt'):
    print(f'*** Loading final checkpoint file {checkpoint_file_final} instead of training')
    checkpoint_file = checkpoint_file_final
else:
    res = trainer.fit(dl_train, dl_test,
                      num_epochs=200, early_stopping=20, print_every=10,
                      checkpoints=checkpoint_file,
                      post_epoch_fn=post_epoch_fn)
    
# Plot images from best model
saved_state = torch.load(f'{checkpoint_file}.pt', map_location=device)
vae_dp.load_state_dict(saved_state['model_state'])
print('*** Images Generated from best model:')
fig, _ = plot.tensors_as_images(vae_dp.module.sample(n=15), nrows=3, figsize=(6,6))
# Out:
# --- EPOCH 1/200 ---
# train_batch (Avg. Loss 2126.216, Accuracy 0.0): 100%|██████████████████████████| 5/5 [00:01<00:00,  3.86it/s]
# test_batch (Avg. Loss 1298.764, Accuracy 0.0): 100%|███████████████████████████| 1/1 [00:00<00:00,  8.38it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 1
# train_batch (Avg. Loss 2730.670, Accuracy 0.0): 100%|██████████████████████████| 5/5 [00:01<00:00,  3.77it/s]
# test_batch (Avg. Loss 1479.272, Accuracy 0.0): 100%|███████████████████████████| 1/1 [00:00<00:00,  8.28it/s]
# train_batch (Avg. Loss 1339.645, Accuracy 0.0): 100%|██████████████████████████| 5/5 [00:01<00:00,  3.84it/s]
# test_batch (Avg. Loss 1730.169, Accuracy 0.0): 100%|███████████████████████████| 1/1 [00:00<00:00,  8.44it/s]
# train_batch (Avg. Loss 1249.090, Accuracy 0.0): 100%|██████████████████████████| 5/5 [00:01<00:00,  3.87it/s]
# test_batch (Avg. Loss 1782.044, Accuracy 0.0): 100%|███████████████████████████| 1/1 [00:00<00:00,  8.43it/s]
# train_batch (Avg. Loss 1179.248, Accuracy 0.0): 100%|██████████████████████████| 5/5 [00:01<00:00,  3.97it/s]
# test_batch (Avg. Loss 1731.655, Accuracy 0.0): 100%|███████████████████████████| 1/1 [00:00<00:00,  8.43it/s]
# train_batch (Avg. Loss 1123.654, Accuracy 0.0): 100%|██████████████████████████| 5/5 [00:01<00:00,  4.00it/s]
# test_batch (Avg. Loss 1647.138, Accuracy 0.0): 100%|███████████████████████████| 1/1 [00:00<00:00,  8.53it/s]
# train_batch (Avg. Loss 1082.987, Accuracy 0.0): 100%|██████████████████████████| 5/5 [00:01<00:00,  3.96it/s]
# test_batch (Avg. Loss 1481.890, Accuracy 0.0): 100%|███████████████████████████| 1/1 [00:00<00:00,  8.38it/s]
# train_batch (Avg. Loss 1036.113, Accuracy 0.0): 100%|██████████████████████████| 5/5 [00:01<00:00,  3.94it/s]
# test_batch (Avg. Loss 1396.217, Accuracy 0.0): 100%|███████████████████████████| 1/1 [00:00<00:00,  8.34it/s]
# train_batch (Avg. Loss 1000.514, Accuracy 0.0): 100%|██████████████████████████| 5/5 [00:01<00:00,  3.82it/s]
# test_batch (Avg. Loss 1245.027, Accuracy 0.0): 100%|███████████████████████████| 1/1 [00:00<00:00,  8.39it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 9
# train_batch (Avg. Loss 970.239, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.96it/s]
# test_batch (Avg. Loss 1122.353, Accuracy 0.0): 100%|███████████████████████████| 1/1 [00:00<00:00,  8.56it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 10
# --- EPOCH 11/200 ---
# train_batch (Avg. Loss 933.020, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.98it/s]
# test_batch (Avg. Loss 1000.872, Accuracy 0.0): 100%|███████████████████████████| 1/1 [00:00<00:00,  8.46it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 11
# train_batch (Avg. Loss 900.442, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.81it/s]
# test_batch (Avg. Loss 934.851, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.39it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 12
# train_batch (Avg. Loss 867.409, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.94it/s]
# test_batch (Avg. Loss 872.437, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.48it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 13
# train_batch (Avg. Loss 855.345, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.94it/s]
# test_batch (Avg. Loss 843.918, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.39it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 14
# train_batch (Avg. Loss 833.365, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.95it/s]
# test_batch (Avg. Loss 800.073, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.28it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 15
# train_batch (Avg. Loss 811.649, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.94it/s]
# test_batch (Avg. Loss 787.973, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.48it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 16
# train_batch (Avg. Loss 801.494, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.95it/s]
# test_batch (Avg. Loss 763.613, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.41it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 17
# train_batch (Avg. Loss 783.076, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.95it/s]
# test_batch (Avg. Loss 770.472, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.40it/s]
# train_batch (Avg. Loss 775.903, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.91it/s]
# test_batch (Avg. Loss 736.817, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.25it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 19
# train_batch (Avg. Loss 765.415, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.93it/s]
# test_batch (Avg. Loss 730.226, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.50it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 20
# --- EPOCH 21/200 ---
# train_batch (Avg. Loss 752.021, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.89it/s]
# test_batch (Avg. Loss 721.044, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.34it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 21
# train_batch (Avg. Loss 749.921, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.93it/s]
# test_batch (Avg. Loss 712.768, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.28it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 22
# train_batch (Avg. Loss 734.856, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.93it/s]
# test_batch (Avg. Loss 714.428, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.46it/s]
# train_batch (Avg. Loss 729.473, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.82it/s]
# test_batch (Avg. Loss 691.974, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.14it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 24
# train_batch (Avg. Loss 718.585, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.94it/s]
# test_batch (Avg. Loss 692.624, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.29it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 25
# train_batch (Avg. Loss 712.995, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.83it/s]
# test_batch (Avg. Loss 679.633, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.41it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 26
# train_batch (Avg. Loss 704.770, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.95it/s]
# test_batch (Avg. Loss 670.562, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.35it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 27
# train_batch (Avg. Loss 698.667, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.69it/s]
# test_batch (Avg. Loss 679.668, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.48it/s]
# train_batch (Avg. Loss 695.482, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.90it/s]
# test_batch (Avg. Loss 679.071, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.51it/s]
# train_batch (Avg. Loss 690.937, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.98it/s]
# test_batch (Avg. Loss 670.034, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.57it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 30
# --- EPOCH 31/200 ---
# train_batch (Avg. Loss 682.596, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.85it/s]
# test_batch (Avg. Loss 656.936, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.55it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 31
# train_batch (Avg. Loss 684.137, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.89it/s]
# test_batch (Avg. Loss 657.067, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.83it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 32
# train_batch (Avg. Loss 677.826, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.84it/s]
# test_batch (Avg. Loss 648.412, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.51it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 33
# train_batch (Avg. Loss 671.116, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.90it/s]
# test_batch (Avg. Loss 644.674, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.51it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 34
# train_batch (Avg. Loss 672.707, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.90it/s]
# test_batch (Avg. Loss 660.950, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.53it/s]
# train_batch (Avg. Loss 666.953, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.96it/s]
# test_batch (Avg. Loss 651.372, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.62it/s]
# train_batch (Avg. Loss 663.316, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.91it/s]
# test_batch (Avg. Loss 650.004, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.98it/s]
# train_batch (Avg. Loss 659.387, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.95it/s]
# test_batch (Avg. Loss 650.927, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.58it/s]
# train_batch (Avg. Loss 654.563, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.91it/s]
# test_batch (Avg. Loss 630.524, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.33it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 39
# train_batch (Avg. Loss 652.597, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.88it/s]
# test_batch (Avg. Loss 644.526, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.27it/s]
# --- EPOCH 41/200 ---
# train_batch (Avg. Loss 644.697, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.83it/s]
# test_batch (Avg. Loss 619.833, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.19it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 41
# train_batch (Avg. Loss 644.482, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.86it/s]
# test_batch (Avg. Loss 643.880, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.41it/s]
# train_batch (Avg. Loss 642.192, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.91it/s]
# test_batch (Avg. Loss 622.668, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.38it/s]
# train_batch (Avg. Loss 638.756, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.96it/s]
# test_batch (Avg. Loss 645.347, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.48it/s]
# train_batch (Avg. Loss 644.740, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.94it/s]
# test_batch (Avg. Loss 624.167, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.29it/s]
# train_batch (Avg. Loss 637.480, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.87it/s]
# test_batch (Avg. Loss 633.914, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.12it/s]
# train_batch (Avg. Loss 630.498, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.87it/s]
# test_batch (Avg. Loss 637.985, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.58it/s]
# train_batch (Avg. Loss 631.829, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.94it/s]
# test_batch (Avg. Loss 626.021, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.93it/s]
# train_batch (Avg. Loss 630.475, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.87it/s]
# test_batch (Avg. Loss 629.637, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.61it/s]
# train_batch (Avg. Loss 623.750, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.85it/s]
# test_batch (Avg. Loss 625.297, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.20it/s]
# --- EPOCH 51/200 ---
# train_batch (Avg. Loss 615.574, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.86it/s]
# test_batch (Avg. Loss 619.871, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.49it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 51
# train_batch (Avg. Loss 616.301, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.94it/s]
# test_batch (Avg. Loss 615.918, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.55it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 52
# train_batch (Avg. Loss 613.774, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.90it/s]
# test_batch (Avg. Loss 618.909, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.37it/s]
# train_batch (Avg. Loss 611.923, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.89it/s]
# test_batch (Avg. Loss 615.378, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.54it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 54
# train_batch (Avg. Loss 604.871, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.93it/s]
# test_batch (Avg. Loss 613.897, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.23it/s]
# train_batch (Avg. Loss 602.498, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.92it/s]
# test_batch (Avg. Loss 619.124, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.22it/s]
# train_batch (Avg. Loss 605.179, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.99it/s]
# test_batch (Avg. Loss 615.489, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.35it/s]
# train_batch (Avg. Loss 603.615, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.96it/s]
# test_batch (Avg. Loss 615.240, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.34it/s]
# train_batch (Avg. Loss 595.600, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.98it/s]
# test_batch (Avg. Loss 609.999, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.25it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 59
# train_batch (Avg. Loss 592.597, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.96it/s]
# test_batch (Avg. Loss 600.984, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.61it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 60
# --- EPOCH 61/200 ---
# train_batch (Avg. Loss 588.836, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.94it/s]
# test_batch (Avg. Loss 613.667, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.48it/s]
# train_batch (Avg. Loss 595.645, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.95it/s]
# test_batch (Avg. Loss 602.689, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.44it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 62
# train_batch (Avg. Loss 591.705, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.76it/s]
# test_batch (Avg. Loss 604.657, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.35it/s]
# train_batch (Avg. Loss 588.169, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.90it/s]
# test_batch (Avg. Loss 606.436, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.25it/s]
# train_batch (Avg. Loss 582.550, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.84it/s]
# test_batch (Avg. Loss 605.362, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.99it/s]
# train_batch (Avg. Loss 584.319, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.69it/s]
# test_batch (Avg. Loss 598.875, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.35it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 66
# train_batch (Avg. Loss 576.971, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.81it/s]
# test_batch (Avg. Loss 592.856, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.39it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 67
# train_batch (Avg. Loss 579.428, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.87it/s]
# test_batch (Avg. Loss 607.379, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.31it/s]
# train_batch (Avg. Loss 581.568, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.00it/s]
# test_batch (Avg. Loss 600.836, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.22it/s]
# train_batch (Avg. Loss 575.436, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.51it/s]
# test_batch (Avg. Loss 595.817, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.87it/s]
# --- EPOCH 71/200 ---
# train_batch (Avg. Loss 575.430, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.70it/s]
# test_batch (Avg. Loss 603.635, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.51it/s]
# train_batch (Avg. Loss 573.365, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.84it/s]
# test_batch (Avg. Loss 600.618, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.33it/s]
# train_batch (Avg. Loss 570.573, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.91it/s]
# test_batch (Avg. Loss 584.641, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.52it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 73
# train_batch (Avg. Loss 569.032, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  2.98it/s]
# test_batch (Avg. Loss 594.113, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.66it/s]
# train_batch (Avg. Loss 566.865, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.91it/s]
# test_batch (Avg. Loss 591.801, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.40it/s]
# train_batch (Avg. Loss 560.134, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.85it/s]
# test_batch (Avg. Loss 591.998, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.16it/s]
# train_batch (Avg. Loss 559.551, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.85it/s]
# test_batch (Avg. Loss 593.269, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.26it/s]
# train_batch (Avg. Loss 561.588, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.89it/s]
# test_batch (Avg. Loss 598.826, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.51it/s]
# train_batch (Avg. Loss 556.302, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.93it/s]
# test_batch (Avg. Loss 590.606, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.59it/s]
# train_batch (Avg. Loss 552.736, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.92it/s]
# test_batch (Avg. Loss 585.418, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.53it/s]
# --- EPOCH 81/200 ---
# train_batch (Avg. Loss 555.592, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.90it/s]
# test_batch (Avg. Loss 586.406, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.29it/s]
# train_batch (Avg. Loss 553.950, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.79it/s]
# test_batch (Avg. Loss 574.057, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.31it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 82
# train_batch (Avg. Loss 553.033, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.65it/s]
# test_batch (Avg. Loss 581.921, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.30it/s]
# train_batch (Avg. Loss 550.493, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.81it/s]
# test_batch (Avg. Loss 582.065, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.09it/s]
# train_batch (Avg. Loss 547.775, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.76it/s]
# test_batch (Avg. Loss 587.989, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.12it/s]
# train_batch (Avg. Loss 547.160, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.91it/s]
# test_batch (Avg. Loss 584.256, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.24it/s]
# train_batch (Avg. Loss 543.982, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.70it/s]
# test_batch (Avg. Loss 585.392, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.32it/s]
# train_batch (Avg. Loss 548.058, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.88it/s]
# test_batch (Avg. Loss 588.723, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.41it/s]
# train_batch (Avg. Loss 547.258, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.81it/s]
# test_batch (Avg. Loss 590.772, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.12it/s]
# train_batch (Avg. Loss 554.210, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.79it/s]
# test_batch (Avg. Loss 595.789, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.13it/s]
# --- EPOCH 91/200 ---
# train_batch (Avg. Loss 547.808, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.82it/s]
# test_batch (Avg. Loss 587.652, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.31it/s]
# train_batch (Avg. Loss 551.885, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.82it/s]
# test_batch (Avg. Loss 590.708, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.22it/s]
# train_batch (Avg. Loss 547.536, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.88it/s]
# test_batch (Avg. Loss 590.664, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.10it/s]
# train_batch (Avg. Loss 537.858, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.82it/s]
# test_batch (Avg. Loss 581.459, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.99it/s]
# train_batch (Avg. Loss 539.369, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.83it/s]
# test_batch (Avg. Loss 590.481, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.16it/s]
# train_batch (Avg. Loss 534.767, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.89it/s]
# test_batch (Avg. Loss 580.332, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.53it/s]
# train_batch (Avg. Loss 531.147, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.91it/s]
# test_batch (Avg. Loss 587.324, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.61it/s]
# train_batch (Avg. Loss 530.429, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.81it/s]
# test_batch (Avg. Loss 589.084, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.79it/s]
# train_batch (Avg. Loss 527.102, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.74it/s]
# test_batch (Avg. Loss 575.543, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.86it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 99
# train_batch (Avg. Loss 525.877, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.77it/s]
# test_batch (Avg. Loss 579.770, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.04it/s]
# --- EPOCH 101/200 ---
# train_batch (Avg. Loss 524.204, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.72it/s]
# test_batch (Avg. Loss 578.654, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.29it/s]
# train_batch (Avg. Loss 523.163, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.85it/s]
# test_batch (Avg. Loss 569.823, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.40it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 102
# train_batch (Avg. Loss 524.777, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.86it/s]
# test_batch (Avg. Loss 578.640, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.34it/s]
# train_batch (Avg. Loss 520.795, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.84it/s]
# test_batch (Avg. Loss 579.325, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.40it/s]
# train_batch (Avg. Loss 518.790, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.72it/s]
# test_batch (Avg. Loss 573.450, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  6.15it/s]
# train_batch (Avg. Loss 516.825, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.88it/s]
# test_batch (Avg. Loss 589.341, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.37it/s]
# train_batch (Avg. Loss 522.407, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.75it/s]
# test_batch (Avg. Loss 575.715, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.25it/s]
# train_batch (Avg. Loss 519.561, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.81it/s]
# test_batch (Avg. Loss 580.088, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.13it/s]
# train_batch (Avg. Loss 519.892, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.82it/s]
# test_batch (Avg. Loss 579.617, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.04it/s]
# train_batch (Avg. Loss 510.723, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.82it/s]
# test_batch (Avg. Loss 577.876, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.28it/s]
# --- EPOCH 111/200 ---
# train_batch (Avg. Loss 513.152, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.81it/s]
# test_batch (Avg. Loss 574.531, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.92it/s]
# train_batch (Avg. Loss 515.783, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.88it/s]
# test_batch (Avg. Loss 571.397, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  6.79it/s]
# train_batch (Avg. Loss 512.487, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.76it/s]
# test_batch (Avg. Loss 570.707, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.68it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 113
# train_batch (Avg. Loss 513.565, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.60it/s]
# test_batch (Avg. Loss 571.510, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.65it/s]
# train_batch (Avg. Loss 511.211, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.78it/s]
# test_batch (Avg. Loss 574.849, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.19it/s]
# train_batch (Avg. Loss 505.968, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.80it/s]
# test_batch (Avg. Loss 577.202, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.53it/s]
# train_batch (Avg. Loss 504.019, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.84it/s]
# test_batch (Avg. Loss 576.562, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.41it/s]
# train_batch (Avg. Loss 506.619, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.86it/s]
# test_batch (Avg. Loss 574.388, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.36it/s]
# train_batch (Avg. Loss 501.869, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.83it/s]
# test_batch (Avg. Loss 582.388, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.26it/s]
# train_batch (Avg. Loss 500.520, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.87it/s]
# test_batch (Avg. Loss 572.690, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.07it/s]
# --- EPOCH 121/200 ---
# train_batch (Avg. Loss 500.582, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.90it/s]
# test_batch (Avg. Loss 574.518, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.36it/s]
# train_batch (Avg. Loss 501.666, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.77it/s]
# test_batch (Avg. Loss 571.226, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.29it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 122
# train_batch (Avg. Loss 500.581, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.88it/s]
# test_batch (Avg. Loss 568.089, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.25it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 123
# train_batch (Avg. Loss 495.981, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.75it/s]
# test_batch (Avg. Loss 565.394, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.16it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 124
# train_batch (Avg. Loss 492.706, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.86it/s]
# test_batch (Avg. Loss 575.327, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.13it/s]
# train_batch (Avg. Loss 492.276, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.88it/s]
# test_batch (Avg. Loss 568.930, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.42it/s]
# train_batch (Avg. Loss 500.921, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.77it/s]
# test_batch (Avg. Loss 572.925, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.14it/s]
# train_batch (Avg. Loss 495.267, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.86it/s]
# test_batch (Avg. Loss 566.721, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.36it/s]
# train_batch (Avg. Loss 491.904, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.85it/s]
# test_batch (Avg. Loss 584.876, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.79it/s]
# train_batch (Avg. Loss 493.003, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.68it/s]
# test_batch (Avg. Loss 571.101, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  5.75it/s]
# --- EPOCH 131/200 ---
# train_batch (Avg. Loss 493.116, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.87it/s]
# test_batch (Avg. Loss 577.893, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.25it/s]
# train_batch (Avg. Loss 490.108, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.89it/s]
# test_batch (Avg. Loss 567.002, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.29it/s]
# train_batch (Avg. Loss 487.639, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.87it/s]
# test_batch (Avg. Loss 566.478, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.37it/s]
# train_batch (Avg. Loss 494.065, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.80it/s]
# test_batch (Avg. Loss 569.748, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.96it/s]
# train_batch (Avg. Loss 491.766, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.78it/s]
# test_batch (Avg. Loss 565.570, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.01it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 135
# train_batch (Avg. Loss 483.392, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.77it/s]
# test_batch (Avg. Loss 561.496, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.69it/s]
# *** Saved checkpoint checkpoints/vae.pt at epoch 136
# train_batch (Avg. Loss 480.474, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.45it/s]
# test_batch (Avg. Loss 570.356, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.24it/s]
# train_batch (Avg. Loss 485.322, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.82it/s]
# test_batch (Avg. Loss 570.478, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.83it/s]
# train_batch (Avg. Loss 487.622, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.82it/s]
# test_batch (Avg. Loss 569.798, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.85it/s]
# train_batch (Avg. Loss 500.640, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.87it/s]
# test_batch (Avg. Loss 577.282, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.92it/s]
# --- EPOCH 141/200 ---
# train_batch (Avg. Loss 495.595, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.61it/s]
# test_batch (Avg. Loss 574.958, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.87it/s]
# train_batch (Avg. Loss 493.317, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.85it/s]
# test_batch (Avg. Loss 584.266, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.13it/s]
# train_batch (Avg. Loss 486.614, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.83it/s]
# test_batch (Avg. Loss 572.659, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  5.27it/s]
# train_batch (Avg. Loss 481.275, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.64it/s]
# test_batch (Avg. Loss 577.599, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.22it/s]
# train_batch (Avg. Loss 480.356, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.78it/s]
# test_batch (Avg. Loss 566.051, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  7.98it/s]
# train_batch (Avg. Loss 480.189, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.73it/s]
# test_batch (Avg. Loss 568.963, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.07it/s]
# train_batch (Avg. Loss 477.180, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.72it/s]
# test_batch (Avg. Loss 565.943, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.24it/s]
# train_batch (Avg. Loss 476.249, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.84it/s]
# test_batch (Avg. Loss 560.439, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.19it/s]
# train_batch (Avg. Loss 472.153, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.77it/s]
# test_batch (Avg. Loss 568.520, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.20it/s]
# train_batch (Avg. Loss 471.440, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.62it/s]
# test_batch (Avg. Loss 562.811, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.21it/s]
# --- EPOCH 151/200 ---
# train_batch (Avg. Loss 470.539, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.81it/s]
# test_batch (Avg. Loss 559.625, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.11it/s]
# train_batch (Avg. Loss 469.955, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.83it/s]
# test_batch (Avg. Loss 568.019, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.19it/s]
# train_batch (Avg. Loss 469.984, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.85it/s]
# test_batch (Avg. Loss 566.393, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.18it/s]
# train_batch (Avg. Loss 473.062, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.79it/s]
# test_batch (Avg. Loss 565.174, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.17it/s]
# train_batch (Avg. Loss 468.242, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.80it/s]
# test_batch (Avg. Loss 567.843, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.54it/s]
# train_batch (Avg. Loss 467.264, Accuracy 0.0): 100%|███████████████████████████| 5/5 [00:01<00:00,  3.76it/s]
# test_batch (Avg. Loss 571.661, Accuracy 0.0): 100%|████████████████████████████| 1/1 [00:00<00:00,  8.54it/s]
# *** Images Generated from best model:
# /tmp/ipykernel_2688472/3902647951.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   saved_state = torch.load(f'{checkpoint_file}.pt', map_location=device)

# %% [markdown]
# ## Questions
# <a id=part2_7></a>

# %% [markdown]
# **TODO** Answer the following questions. Write your answers in the appropriate variables in the module `hw3/answers.py`.

# %%
from cs236781.answers import display_answer
import hw3.answers

# %% [markdown]
# ### Question 1
#
# What does the $\sigma^2$ hyperparameter (`x_sigma2` in the code) do? Explain the effect of low and high values.

# %%
display_answer(hw3.answers.part2_q1)

# %% [markdown]
# ### Question 2
#
# 1. Explain the purpose of both parts of the VAE loss term - reconstruction loss and KL divergence loss.
# 2. How is the latent-space distribution affected by the KL loss term?
# 3. What's the benefit of this effect?

# %%
display_answer(hw3.answers.part2_q2)

# %% [markdown]
# ### Question 3
#
# In the formulation of the VAE loss, why do we start by maximizing the evidence
# distribution, $p(X)$?

# %%
display_answer(hw3.answers.part2_q3)

# %% [markdown]
# ### Question 4
#
# In the VAE encoder, why do we model the **log** of the
# latent-space variance corresponding to an input, $\sigma^2_{\alpha}$,
# instead of directly modelling this variance?

# %%
display_answer(hw3.answers.part2_q4)
